# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,20)
y = x * x
z = x + y

# %%
plt.plot(x,y)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,1,1])
plt.savefig("./image/oop1.png")

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.3,1,1])
plt.savefig("./image/oop2.png")

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.3,1,1])
axes.plot(x,y)
plt.savefig("./image/oop3.png")
