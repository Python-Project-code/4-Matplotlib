# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,20)
y = x * x
z = x + y

# %%
plt.plot(x,y)
plt.savefig('./image/t1.png')

# %%
plt.scatter(x,y)
plt.savefig('./image/t2.png')

# %%
plt.hist(x,y)
plt.savefig('./image/t3.png')

# %%
plt.bar(x,y)
plt.savefig('./image/t4.png')

# %%
plt.fill(x,y)
plt.savefig('./image/t5.png')

# %%
plt.polar(x,y)
plt.savefig('./image/t6.png')

# %%
plt.polar(x,y)
plt.savefig('./image/t7.png')
