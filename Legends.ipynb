# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,20)
y = x * x
z = x + y

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,label = 'First example')
plt.legend()
