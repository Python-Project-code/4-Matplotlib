# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,20)
y = x * x
z = x + y

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,label = 'First example')
plt.legend()
plt.savefig("./image/fe.png")

# %%
plt.plot(x,y,y,x,label = 'First example')
plt.legend()
plt.savefig("./image/l2.png")

# %%
plt.plot(x,y,y,x,label = 'First example')
plt.legend(loc = 2)
plt.savefig("./image/l3.png")

# %%
plt.plot(x,y,y,x,label = 'First example')
plt.legend(loc = 10)
plt.savefig("./image/l4.png")
