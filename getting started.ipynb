# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,20)
y = x * x
z = x + y

# %%
plt.plot(x,y)

# %%
plt.plot(x,x)

# %%
plt.plot(x,y,x,x)
# Out:
# [<matplotlib.lines.Line2D at 0x7f4fa177f0b8>,
#  <matplotlib.lines.Line2D at 0x7f4fa177f128>]

# %%
plt.plot(x,x)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('First title')
plt.savefig('./image/first_title.png')
