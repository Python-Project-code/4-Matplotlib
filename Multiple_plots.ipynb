# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,20)
y = x * x
z = x + y

# %%
fig = plt.figure()
x1 = fig.add_axes([0.1,0.1,0.8,0.8])
x2 =  fig.add_axes([0.3,0.3,0.3,0.3])
plt.savefig("./image/oop4.png")

# %%
fig = plt.figure()
x1 = fig.add_axes([0.1,0.1,0.8,0.8])
x1.plot(x,y)
x2 =  fig.add_axes([0.3,0.3,0.3,0.3])
x2.plot(y,x)
plt.savefig("./image/oop5.png")

# %% [markdown]
# # Subplots using object oriented

# %%
fig ,axes = plt.subplots(1,2)
axes[0].plot(x,y)
axes[1].plot(y,x)
plt.tight_layout()
plt.savefig("./image/006.png")
